# %%
import random

tong = 0
b = 0
computerchoice = 1
kt = True
while kt == True:
    a = random.randint(0, 1)
    if a == 0:
        current_player  = "human"
        print('Lượt chơi của người chơi')
        b = int(input('Người chơi chọn: ')) #playerchoice là lựa chọn của người chơi trong khoảng 1,2,3
        while b not in(1,2,3):
            print('Nhập số trong khoảng 1-3: ')
            b = int(input('playerchoice: '))
        tong += b
        print('Tổng hiện tại: ', tong)
    else:
        current_player  = "computer"
        print('Lượt chơi của máy')
        computerchoice = random.randint(1,3)
        print('Máy chọn: ',computerchoice)
        tong += computerchoice
        print('Tổng hiện tại: ', tong)
    
    if tong >= 21 and a == 0:
        print('Người chơi thua')
        answer = str(input('Run again? (y/n): '))
        if answer == "y":
            tong = 0
            continue
        else:
            print('Goodbye')
            break
    if tong >= 21 and a == 1:
        print('Máy thua')
        answer = str(input('Run again? (y/n): '))
        if answer == "y":
            tong = 0
            continue
        else:
            print('Goodbye')
            break
# Out:
# Lượt chơi của người chơi
# Người chơi chọn: 4
# Nhập số trong khoảng 1-3:
# playerchoice: 0
# Nhập số trong khoảng 1-3:
# playerchoice: 2
# Tổng hiện tại:  2
# Lượt chơi của máy
# Máy chọn:  3
# Tổng hiện tại:  5
# Lượt chơi của máy
# Máy chọn:  1
# Tổng hiện tại:  6
# Lượt chơi của máy
# Máy chọn:  3
# Tổng hiện tại:  9
# Lượt chơi của máy
# Máy chọn:  2
# Tổng hiện tại:  11
# Lượt chơi của máy
# Máy chọn:  1
# Tổng hiện tại:  12
# Lượt chơi của máy
# Máy chọn:  2
# Tổng hiện tại:  14
# Lượt chơi của người chơi
# Người chơi chọn: 3
# Tổng hiện tại:  17
# Lượt chơi của người chơi
# Người chơi chọn: 3
# Tổng hiện tại:  20
# Lượt chơi của máy
# Máy chọn:  3
# Tổng hiện tại:  23
# Máy thua
# Run again? (y/n): n
# Goodbye
